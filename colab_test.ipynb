# %%
# !pip install genesis-forge
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.8/232.8 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 MB 11.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 42.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 73.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 22.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.2/408.2 kB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.1/583.1 kB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 105.9 MB/s eta 0:00:0000:01
# ...

# %%
# !pip install tensorboard rsl-rl-lib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 754.2/754.2 kB 55.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 75.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 14.6 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/SirJuanGod/Duck-Duck-Go.git
# Out:
# fatal: destination path 'Duck-Duck-Go' already exists and is not an empty directory.

# %%
# %cd Duck-Duck-Go
# !git pull
# Out:
# [Errno 2] No such file or directory: 'Duck-Duck-Go'
# /content/Duck-Duck-Go
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.01 KiB | 343.00 KiB/s, done.
# From https://github.com/SirJuanGod/Duck-Duck-Go
#    f84ee14..41482c6  main       -> origin/main
# Updating f84ee14..41482c6
# Fast-forward
#  colab_test.ipynb | 62 ++++++++++++++++++++++++++++++++++++++++----------------
#  environment.py   |  2 +-
#  2 files changed, 46 insertions(+), 18 deletions(-)

# %%
# %ls
# Out:
# checker.png       environment.py  __pycache__/  train.py
# colab_test.ipynb  model/          Reference/

# %%
# %cat environment.py
# Out:
# import genesis as gs
# import torch
# import os
# from PIL import Image
# import numpy as np
#
# from genesis_forge import ManagedEnvironment, EnvMode
# from genesis_forge.managers import (
#     RewardManager,
#     TerminationManager,
#     EntityManager,
#     ObservationManager,
#     ActuatorManager,
#     PositionActionManager,
#     VelocityCommandManager,
#     TerrainManager,
#     ContactManager
# )
# from genesis_forge.mdp import reset, terminations, observations, rewards
#
# HEIGHT_OFFSET = 0.09
# INITIAL_BODY_POSITION = [0.0, 0.0, HEIGHT_OFFSET]
# INITIAL_QUAT = [1.0, 0.0, 0.0, 0.0]
#
# def pose_to_T(pos=(0.0, 0.0, 0.0), quat=(1.0, 0.0, 0.0, 0.0)):
#     """Convierte posicion (x,y,z) y cuaternion (w,x,y,z) a matriz homogenea 4x4."""
#     w, x, y, z = quat
#     R = np.array([
#         [1 - 2*(y*y + z*z),  2*(x*y - w*z),      2*(x*z + w*y)],
#         [2*(x*y + w*z),      1 - 2*(x*x + z*z),  2*(y*z - w*x)],
# ...

# %%
# %%python train.py --no_video
# Out:
# [Limpieza] Borrando logs del experimento anterior en logs/duckduck_locomotion...
# [Genesis] [01:07:06] [WARNING] Mesh is not watertight. Falling back to convex hull for estimating inertial properties.
# [Genesis] [01:07:06] [WARNING] Geom idx 0 is not watertight; skipping wall-thickness SDF refinement.
# [Genesis] [01:07:10] [WARNING] Mesh is not watertight. Falling back to convex hull for estimating inertial properties.
# [Genesis] [01:07:10] [WARNING] Mesh is not watertight. Falling back to convex hull for estimating inertial properties.
# [Genesis] [01:07:11] [WARNING] Mesh is not watertight. Falling back to convex hull for estimating inertial properties.
# Video desactivado. Solo se guardaran checkpoints.
# Traceback (most recent call last):
#   File "/content/Duck-Duck-Go/train.py", line 86, in <module>
#     env.build()
#     ~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/genesis_forge/wrappers/wrapper.py", line 100, in build
#     self.env.build()
# ...
